# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %%
url = "mysql+pymysql://root:root@localhost:3306/mlops"
engine = create_engine(url)

# %%
sql="""select *
from mlops.credit_score_features
"""

# %%
with engine.connect() as conn:
    df = pd.read_sql(sql, con=conn.connection)
# Out:
# /tmp/ipykernel_38673/1271460178.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, con=conn.connection)

# %%
df
# Out:
#            id customer_id        date           name   age        ssn  \
# 0      100127       23186  2025-06-12        Gillams  42.0  486471751
# 1      100138        6601  2025-05-12         Cableo  31.0  534541028
# 2      100188       42573  2025-07-30  Nick Edwardsl  42.0  190660409
# 3      100234       36210  2025-05-30      Hideyukih  32.0  200137091
# 4      100236       36210  2025-07-30      Hideyukih  32.0  200137091
# ...       ...         ...         ...            ...   ...        ...
# 19995   99946       19334  2025-05-03     Nachtigalh  19.0  942965677
# 19996   99978       20482  2025-01-25    Ann Saphird  18.0  913935303
# 19997   99982       20482  2025-05-27    Ann Saphird  18.0  913935303
# 19998   99991       13373  2025-02-27     Joseph A.p  42.0   45126597
# 19999   99993       13373  2025-04-27     Joseph A.p  42.0   45126597
#
#          occupation  annual_income  monthly_inhand_salary  num_bank_accounts  \
# 0            Doctor       124534.0               10621.90                1.0
# 1      Entrepreneur        14542.3                1480.86                6.0
# 2            Doctor        30117.4                2312.78                7.0
# 3      Entrepreneur        63371.6                5533.96                6.0
# 4      Entrepreneur        63371.6                5533.96                6.0
# ...             ...            ...                    ...                ...
# 19995       Manager        17565.6                1588.80               10.0
# 19996     Developer        63402.2                5475.52                5.0
# 19997     Developer        63402.2                5475.52                5.0
# 19998     Architect        16021.1                1583.09                8.0
# 19999     Architect        16021.1                1583.09                8.0
#
#        ...  num_credit_inquiries  credit_mix  outstanding_debt  \
# 0      ...                   1.0        Good            757.38
# 1      ...                   8.0         Bad           4479.00
# 2      ...                  11.0    Standard           1512.32
# 3      ...                   7.0    Standard            756.94
# 4      ...                   7.0    Standard            756.94
# ...    ...                   ...         ...               ...
# 19995  ...                  12.0         Bad           2986.89
# 19996  ...                   5.0    Standard           2153.66
# 19997  ...                   5.0    Standard           2153.66
# 19998  ...                   5.0    Standard           2136.31
# 19999  ...                   5.0    Standard           2136.31
#
#       credit_utilization_ratio  credit_history_age  payment_of_min_amount  \
# 0                      27.8458               214.0                     No
# 1                      39.3129                11.0                    Yes
# 2                      29.9881                71.0                    Yes
# 3                      25.1793               324.0                     No
# 4                      33.0600               326.0                     No
# ...                        ...                 ...                    ...
# 19995                  27.9395                79.0                     NM
# 19996                  33.8446               227.0                    Yes
# 19997                  35.0262               231.0                    Yes
# 19998                  27.8083               195.0                    Yes
# 19999                  31.0242               197.0                    Yes
#
#        total_emi_per_month  amount_invested_monthly  \
# 0                 174.3390                 235.1290
# 1                  63.1120                  61.1033
# 2                  51.1406                 130.8600
# 3                 104.8700                 404.6060
# 4                 104.8700                 234.3650
# ...                    ...                      ...
# 19995             100.6370                  71.7781
# 19996             152.1060                 166.3060
# 19997             152.1060               10000.0000
# 19998              30.6314                  45.0026
# 19999              30.6314                 121.8680
#
#                       payment_behaviour  monthly_balance
# 0       High_spent_Large_value_payments          892.719
# 1      High_spent_Medium_value_payments          273.871
# 2        Low_spent_Small_value_payments          339.278
# 3       Low_spent_Medium_value_payments          323.920
# 4       High_spent_Small_value_payments          474.161
# ...                                 ...              ...
# 19995   Low_spent_Medium_value_payments          266.464
# 19996   High_spent_Small_value_payments          489.140
# 19997   High_spent_Small_value_payments          404.639
# 19998  High_spent_Medium_value_payments          332.676
# 19999    Low_spent_Small_value_payments          285.810
#
# [20000 rows x 27 columns]
